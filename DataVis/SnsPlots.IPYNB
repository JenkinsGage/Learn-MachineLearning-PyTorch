# %%
import torch
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Heatmap
flights = sns.load_dataset('flights')
print(flights)
flights = flights.pivot('month', 'year', 'passengers')
sns.heatmap(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# C:\Users\indie\AppData\Local\Temp\ipykernel_15904\3466127055.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot('month', 'year', 'passengers')
# <Axes: xlabel='year', ylabel='month'>

# %%
df = sns.load_dataset('tips')
print(df)
sns.boxplot(data=df, x='day', y='total_bill')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df = sns.load_dataset('tips')
print(df)
sns.histplot(data=df, x='total_bill', hue='sex', multiple='dodge')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df = sns.load_dataset('flights')
print(df)
sns.lineplot(data=df, x='year', y='passengers')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.set_palette("Set2")

df = sns.load_dataset('tips')
print(df)
sns.scatterplot(data=df, x='total_bill', y='tip', hue='smoker')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = [['ResNet18', 802.7, 68.4],
        ['Xception', 245.6, 95.6],
        ['MobileNet V2', 785.7, 97.8],
        ['ShuffleNet V2', 803.7, 98.36]]

df = pd.DataFrame(data=data, columns=['Model', 'Speed', 'Accuracy'])
plt.figure(figsize=(4, 5))
sns.scatterplot(x='Speed', y='Accuracy', hue='Model' ,data=df)
# Out:
# <Axes: xlabel='Speed', ylabel='Accuracy'>
